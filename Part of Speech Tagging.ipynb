# %%
#Import all the libraries
import re
import nltk
import pandas as pd
from nltk.tokenize import word_tokenize
from collections import Counter

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
data = pd.read_excel('New  Assignment 1 Dataset.xlsx')

# %%
data
# Out:
#                                               Subject  \
# 0   photoshop , windows , office . cheap . main tr...
# 1   looking for medication ? we ` re the best sour...
# 2                 vocable % rnd - word asceticism\n\n
# 3                                    report 01405 !\n
# 4                                 vic . odin n ^ ow\n
# 5      underpriced issue with high return on equity\n
# 6    jump in to gain substantial ground immediately\n
# 7                             end of year clearance\n
# 8   vlc , 0 dln for sale , no prior pres . crip . ...
# 9                                          jennifer\n
# 10                                         software\n
# 11    security alert on microsoft internet explorer\n
# 12      instant download 1300 popular softwares now\n
# 13                          notification of bequest\n
# 14                the bull reccomends this stokkpic\n
# 15                       re : husband soup would be\n
# 16                                active and strong\n
# 17                                             back\n
# 18                                     new schedule\n
# 19  108 mbps wireless firewall 4 - port router @ $...
# 20                                           vulgar\n
# 21       small stock oppurtunities - their shooting\n
# 22  tinydrive usb 2 . 0 mobile 2 . 2 gb storage dr...
# 23                what she doesnt know sprig bashaw\n
# 24  lose 19 % , powerful weightloss now available ...
# 25                                about celebration\n
# 26  cialis , valium , viagra , xanax at low price ...
# 27                                    young pussies\n
# 28   the bast phharma out ther - same da - y shijp...
# 29                           notebookplus batteries\n
# 30                               from mrs . juliana\n
# 31                                              cat\n
# 32   my brother ' s dream one nlght , i lay in bed...
# 33           collene medg stockplay of the day jeer\n
# 34  access to the images of the catalogues - acced...
# 35                             re :  the cat raised\n
#
#                                               Content
# 0   abasements darer prudently fortuitous undergon...
# 1   it is difficult to make our material condition...
# 2   vcsc - brand new stock for your attention\nvoc...
# 3   wffur attion brom est inst siupied 1 pgst our ...
# 4   berne hotbox carnal bride cutworm dyadic\nguar...
# 5   stock report .\ndont sieep on this stock ! thi...
# 6   we are very excited about this new upcoming st...
# 7   item no #\ndescription\nprice $\n1 .\n2 . 2 gb...
# 8   enjoy up to 80 % off\nbuy vlc , 0 dln online\n...
# 9   sends them to their final destination .\ndesig...
# 10  microsoft windows xp professioznal 2002\nretai...
# 11  dear suntrust bank customer ,\nto provide our ...
# 12  lost lips played sun . remained profession spr...
# 13  from : dr . abdul kareem\nkareem co . ( solici...
# 14  yap internationa | , inc . ( ypil )\nvoip tech...
# 15  as you know election time is not the best thin...
# 16  cialis helps increase blood flow in the penis ...
# 17  emile (\nthe cablefilterz will allow you to re...
# 18  cry born , cow mount record middle . govern , ...
# 19  netgear 108 mbps wireless firewall 4 - port\nr...
# 20  muniz ,\ngovenment don ' t want me to sell\nun...
# 21  haley ,\ntechlite , inc . ( 0 tcbb : thlt )\nj...
# 22  tinydrive 2 . 2 gb . 5 x 2 . 25 x 2 . 5 - inch...
# 23  direct to you\nwarehouse direct\nr _ x discoun...
# 24  hello , i have a special offer for you . . .\n...
# 25  ready , decide eye , heard . once written son ...
# 26  discount rx is simple , quick , and affordable...
# 27  tonya could feel the glow of the hundreds of c...
# 28  hi ! this is for sure one of the best pahrma w...
# 29  visit : http : / / www . computron - me . com ...
# 30  dear friend ,\nplease don ' t be surprised to ...
# 31  logo stationery design\nplease visit our site ...
# 32  then , the shower stopped , and he waved good ...
# 33  watson ,\nmedg - our best pick with rapid grow...
# 34  english\nfranais\ndeutsch\nartprice holds arch...
# 35  our us licensed doctors will\nprescribes your ...

# %%
# Function to clean text from symbols

def clean_text(text):
    # Define a dictionary of abbreviations and their expanded forms
    abbreviations = {
        "re": "are",
        # Add more abbreviations and their expansions as needed
    }
    
    # Create a regex pattern that matches the abbreviations as separate words
    pattern = r'\b(?:{})\b'.format('|'.join(re.escape(key) for key in abbreviations.keys()))
    
    # Replace the abbreviations with their expanded forms
    cleaned_text = re.sub(pattern, lambda match: abbreviations.get(match.group(0)), text)
    
    # Remove symbols except for underscore and whitespace
    cleaned_text = re.sub(r'[^\w\s]', '', cleaned_text)
    
    # Remove single characters
    cleaned_text = re.sub(r'\b\w{1}\b', '', cleaned_text)
    
    return cleaned_text

# %%
data["Clean_Subject"]= data["Subject"].apply(clean_text)
data["Clean_Content"]= data["Content"].apply(clean_text)
data
# Out:
#                                               Subject  \
# 0   photoshop , windows , office . cheap . main tr...
# 1   looking for medication ? we ` re the best sour...
# 2                 vocable % rnd - word asceticism\n\n
# 3                                    report 01405 !\n
# 4                                 vic . odin n ^ ow\n
# 5      underpriced issue with high return on equity\n
# 6    jump in to gain substantial ground immediately\n
# 7                             end of year clearance\n
# 8   vlc , 0 dln for sale , no prior pres . crip . ...
# 9                                          jennifer\n
# 10                                         software\n
# 11    security alert on microsoft internet explorer\n
# 12      instant download 1300 popular softwares now\n
# 13                          notification of bequest\n
# 14                the bull reccomends this stokkpic\n
# 15                       re : husband soup would be\n
# 16                                active and strong\n
# 17                                             back\n
# 18                                     new schedule\n
# 19  108 mbps wireless firewall 4 - port router @ $...
# 20                                           vulgar\n
# 21       small stock oppurtunities - their shooting\n
# 22  tinydrive usb 2 . 0 mobile 2 . 2 gb storage dr...
# 23                what she doesnt know sprig bashaw\n
# 24  lose 19 % , powerful weightloss now available ...
# 25                                about celebration\n
# 26  cialis , valium , viagra , xanax at low price ...
# 27                                    young pussies\n
# 28   the bast phharma out ther - same da - y shijp...
# 29                           notebookplus batteries\n
# 30                               from mrs . juliana\n
# 31                                              cat\n
# 32   my brother ' s dream one nlght , i lay in bed...
# 33           collene medg stockplay of the day jeer\n
# 34  access to the images of the catalogues - acced...
# 35                             re :  the cat raised\n
#
#                                               Content  \
# 0   abasements darer prudently fortuitous undergon...
# 1   it is difficult to make our material condition...
# 2   vcsc - brand new stock for your attention\nvoc...
# 3   wffur attion brom est inst siupied 1 pgst our ...
# 4   berne hotbox carnal bride cutworm dyadic\nguar...
# 5   stock report .\ndont sieep on this stock ! thi...
# 6   we are very excited about this new upcoming st...
# 7   item no #\ndescription\nprice $\n1 .\n2 . 2 gb...
# 8   enjoy up to 80 % off\nbuy vlc , 0 dln online\n...
# 9   sends them to their final destination .\ndesig...
# 10  microsoft windows xp professioznal 2002\nretai...
# 11  dear suntrust bank customer ,\nto provide our ...
# 12  lost lips played sun . remained profession spr...
# 13  from : dr . abdul kareem\nkareem co . ( solici...
# 14  yap internationa | , inc . ( ypil )\nvoip tech...
# 15  as you know election time is not the best thin...
# 16  cialis helps increase blood flow in the penis ...
# 17  emile (\nthe cablefilterz will allow you to re...
# 18  cry born , cow mount record middle . govern , ...
# 19  netgear 108 mbps wireless firewall 4 - port\nr...
# 20  muniz ,\ngovenment don ' t want me to sell\nun...
# 21  haley ,\ntechlite , inc . ( 0 tcbb : thlt )\nj...
# 22  tinydrive 2 . 2 gb . 5 x 2 . 25 x 2 . 5 - inch...
# 23  direct to you\nwarehouse direct\nr _ x discoun...
# 24  hello , i have a special offer for you . . .\n...
# 25  ready , decide eye , heard . once written son ...
# 26  discount rx is simple , quick , and affordable...
# 27  tonya could feel the glow of the hundreds of c...
# 28  hi ! this is for sure one of the best pahrma w...
# 29  visit : http : / / www . computron - me . com ...
# 30  dear friend ,\nplease don ' t be surprised to ...
# 31  logo stationery design\nplease visit our site ...
# 32  then , the shower stopped , and he waved good ...
# 33  watson ,\nmedg - our best pick with rapid grow...
# 34  english\nfranais\ndeutsch\nartprice holds arch...
# 35  our us licensed doctors will\nprescribes your ...
#
#                                         Clean_Subject  \
# 0   photoshop  windows  office  cheap  main trendi...
# 1   looking for medication  we  are the best sourc...
# 2                   vocable  rnd  word asceticism\n\n
# 3                                     report 01405 \n
# 4                                    vic  odin   ow\n
# 5      underpriced issue with high return on equity\n
# 6    jump in to gain substantial ground immediately\n
# 7                             end of year clearance\n
# 8   vlc   dln for sale  no prior pres  crip  tion ...
# 9                                          jennifer\n
# 10                                         software\n
# 11    security alert on microsoft internet explorer\n
# 12      instant download 1300 popular softwares now\n
# 13                          notification of bequest\n
# 14                the bull reccomends this stokkpic\n
# 15                       are  husband soup would be\n
# 16                                active and strong\n
# 17                                             back\n
# 18                                     new schedule\n
# 19  108 mbps wireless firewall   port router   59 ...
# 20                                           vulgar\n
# 21        small stock oppurtunities  their shooting\n
# 22  tinydrive usb    mobile    gb storage drive   ...
# 23                what she doesnt know sprig bashaw\n
# 24  lose 19   powerful weightloss now available wh...
# 25                                about celebration\n
# 26  cialis  valium  viagra  xanax at low price  no...
# 27                                    young pussies\n
# 28   the bast phharma out ther  same da   shijppin...
# 29                           notebookplus batteries\n
# 30                                from mrs  juliana\n
# 31                                              cat\n
# 32   my brother   dream one nlght   lay in bed rea...
# 33           collene medg stockplay of the day jeer\n
# 34  access to the images of the catalogues  accede...
# 35                             are   the cat raised\n
#
#                                         Clean_Content
# 0   abasements darer prudently fortuitous undergon...
# 1   it is difficult to make our material condition...
# 2   vcsc  brand new stock for your attention\nvoca...
# 3   wffur attion brom est inst siupied  pgst our r...
# 4   berne hotbox carnal bride cutworm dyadic\nguar...
# 5   stock report \ndont sieep on this stock  this ...
# 6   we are very excited about this new upcoming st...
# 7   item no \ndescription\nprice \n \n   gb compac...
# 8   enjoy up to 80  off\nbuy vlc   dln online\nget...
# 9   sends them to their final destination \ndesign...
# 10  microsoft windows xp professioznal 2002\nretai...
# 11  dear suntrust bank customer \nto provide our c...
# 12  lost lips played sun  remained profession spri...
# 13  from  dr  abdul kareem\nkareem co   solicitors...
# 14  yap internationa   inc   ypil \nvoip technoiog...
# 15  as you know election time is not the best thin...
# 16  cialis helps increase blood flow in the penis ...
# 17  emile \nthe cablefilterz will allow you to rec...
# 18  cry born  cow mount record middle  govern  nor...
# 19  netgear 108 mbps wireless firewall   port\nrou...
# 20  muniz \ngovenment don   want me to sell\nunder...
# 21  haley \ntechlite  inc    tcbb  thlt \njoint ve...
# 22  tinydrive    gb      25      inches       \n  ...
# 23  direct to you\nwarehouse direct\n   discounts\...
# 24  hello   have  special offer for you   \nwant t...
# 25  ready  decide eye  heard  once written son  vo...
# 26  discount rx is simple  quick  and affordable  ...
# 27  tonya could feel the glow of the hundreds of c...
# 28  hi  this is for sure one of the best pahrma we...
# 29  visit  http    www  computron  me  com for dea...
# 30  dear friend \nplease don   be surprised to rec...
# 31  logo stationery design\nplease visit our site ...
# 32  then  the shower stopped  and he waved good ni...
# 33  watson \nmedg  our best pick with rapid growth...
# 34  english\nfranais\ndeutsch\nartprice holds arch...
# 35  our us licensed doctors will\nprescribes your ...

# %%
# Function to perform part of speech tagging on a single passage
def pos_tagging(passages):
    pos_tags_list = []
    for passage in passages:
        tokens = word_tokenize(passage)
        pos_tags = nltk.pos_tag(tokens)
        pos_tags_list.append(pos_tags)
    return pos_tags_list

# %%
# Function to find the most common words for a specific POS tag
def most_common_words_for_pos(pos_tags_dataset, pos):
    words = [word.lower() for passage in pos_tags_dataset for word, tag in passage if tag.startswith(pos)]
    word_freq = Counter(words)
    return word_freq.most_common(10)

# %%
# Perform part of speech tagging on the passages and add as a new column 'POS_tags'
data['POS_tags_sub'] = pos_tagging(data['Clean_Subject'])
data['POS_tags_cont'] = pos_tagging(data['Clean_Content'])
data
# Out:
#                                               Subject  \
# 0   photoshop , windows , office . cheap . main tr...
# 1   looking for medication ? we ` re the best sour...
# 2                 vocable % rnd - word asceticism\n\n
# 3                                    report 01405 !\n
# 4                                 vic . odin n ^ ow\n
# 5      underpriced issue with high return on equity\n
# 6    jump in to gain substantial ground immediately\n
# 7                             end of year clearance\n
# 8   vlc , 0 dln for sale , no prior pres . crip . ...
# 9                                          jennifer\n
# 10                                         software\n
# 11    security alert on microsoft internet explorer\n
# 12      instant download 1300 popular softwares now\n
# 13                          notification of bequest\n
# 14                the bull reccomends this stokkpic\n
# 15                       re : husband soup would be\n
# 16                                active and strong\n
# 17                                             back\n
# 18                                     new schedule\n
# 19  108 mbps wireless firewall 4 - port router @ $...
# 20                                           vulgar\n
# 21       small stock oppurtunities - their shooting\n
# 22  tinydrive usb 2 . 0 mobile 2 . 2 gb storage dr...
# 23                what she doesnt know sprig bashaw\n
# 24  lose 19 % , powerful weightloss now available ...
# 25                                about celebration\n
# 26  cialis , valium , viagra , xanax at low price ...
# 27                                    young pussies\n
# 28   the bast phharma out ther - same da - y shijp...
# 29                           notebookplus batteries\n
# 30                               from mrs . juliana\n
# 31                                              cat\n
# 32   my brother ' s dream one nlght , i lay in bed...
# 33           collene medg stockplay of the day jeer\n
# 34  access to the images of the catalogues - acced...
# 35                             re :  the cat raised\n
#
#                                               Content  \
# 0   abasements darer prudently fortuitous undergon...
# 1   it is difficult to make our material condition...
# 2   vcsc - brand new stock for your attention\nvoc...
# 3   wffur attion brom est inst siupied 1 pgst our ...
# 4   berne hotbox carnal bride cutworm dyadic\nguar...
# 5   stock report .\ndont sieep on this stock ! thi...
# 6   we are very excited about this new upcoming st...
# 7   item no #\ndescription\nprice $\n1 .\n2 . 2 gb...
# 8   enjoy up to 80 % off\nbuy vlc , 0 dln online\n...
# 9   sends them to their final destination .\ndesig...
# 10  microsoft windows xp professioznal 2002\nretai...
# 11  dear suntrust bank customer ,\nto provide our ...
# 12  lost lips played sun . remained profession spr...
# 13  from : dr . abdul kareem\nkareem co . ( solici...
# 14  yap internationa | , inc . ( ypil )\nvoip tech...
# 15  as you know election time is not the best thin...
# 16  cialis helps increase blood flow in the penis ...
# 17  emile (\nthe cablefilterz will allow you to re...
# 18  cry born , cow mount record middle . govern , ...
# 19  netgear 108 mbps wireless firewall 4 - port\nr...
# 20  muniz ,\ngovenment don ' t want me to sell\nun...
# 21  haley ,\ntechlite , inc . ( 0 tcbb : thlt )\nj...
# 22  tinydrive 2 . 2 gb . 5 x 2 . 25 x 2 . 5 - inch...
# 23  direct to you\nwarehouse direct\nr _ x discoun...
# 24  hello , i have a special offer for you . . .\n...
# 25  ready , decide eye , heard . once written son ...
# 26  discount rx is simple , quick , and affordable...
# 27  tonya could feel the glow of the hundreds of c...
# 28  hi ! this is for sure one of the best pahrma w...
# 29  visit : http : / / www . computron - me . com ...
# 30  dear friend ,\nplease don ' t be surprised to ...
# 31  logo stationery design\nplease visit our site ...
# 32  then , the shower stopped , and he waved good ...
# 33  watson ,\nmedg - our best pick with rapid grow...
# 34  english\nfranais\ndeutsch\nartprice holds arch...
# 35  our us licensed doctors will\nprescribes your ...
#
#                                         Clean_Subject  \
# 0   photoshop  windows  office  cheap  main trendi...
# 1   looking for medication  we  are the best sourc...
# 2                   vocable  rnd  word asceticism\n\n
# 3                                     report 01405 \n
# 4                                    vic  odin   ow\n
# 5      underpriced issue with high return on equity\n
# 6    jump in to gain substantial ground immediately\n
# 7                             end of year clearance\n
# 8   vlc   dln for sale  no prior pres  crip  tion ...
# 9                                          jennifer\n
# 10                                         software\n
# 11    security alert on microsoft internet explorer\n
# 12      instant download 1300 popular softwares now\n
# 13                          notification of bequest\n
# 14                the bull reccomends this stokkpic\n
# 15                       are  husband soup would be\n
# 16                                active and strong\n
# 17                                             back\n
# 18                                     new schedule\n
# 19  108 mbps wireless firewall   port router   59 ...
# 20                                           vulgar\n
# 21        small stock oppurtunities  their shooting\n
# 22  tinydrive usb    mobile    gb storage drive   ...
# 23                what she doesnt know sprig bashaw\n
# 24  lose 19   powerful weightloss now available wh...
# 25                                about celebration\n
# 26  cialis  valium  viagra  xanax at low price  no...
# 27                                    young pussies\n
# 28   the bast phharma out ther  same da   shijppin...
# 29                           notebookplus batteries\n
# 30                                from mrs  juliana\n
# 31                                              cat\n
# 32   my brother   dream one nlght   lay in bed rea...
# 33           collene medg stockplay of the day jeer\n
# 34  access to the images of the catalogues  accede...
# 35                             are   the cat raised\n
#
#                                         Clean_Content  \
# 0   abasements darer prudently fortuitous undergon...
# 1   it is difficult to make our material condition...
# 2   vcsc  brand new stock for your attention\nvoca...
# 3   wffur attion brom est inst siupied  pgst our r...
# 4   berne hotbox carnal bride cutworm dyadic\nguar...
# 5   stock report \ndont sieep on this stock  this ...
# 6   we are very excited about this new upcoming st...
# 7   item no \ndescription\nprice \n \n   gb compac...
# 8   enjoy up to 80  off\nbuy vlc   dln online\nget...
# 9   sends them to their final destination \ndesign...
# 10  microsoft windows xp professioznal 2002\nretai...
# 11  dear suntrust bank customer \nto provide our c...
# 12  lost lips played sun  remained profession spri...
# 13  from  dr  abdul kareem\nkareem co   solicitors...
# 14  yap internationa   inc   ypil \nvoip technoiog...
# 15  as you know election time is not the best thin...
# 16  cialis helps increase blood flow in the penis ...
# 17  emile \nthe cablefilterz will allow you to rec...
# 18  cry born  cow mount record middle  govern  nor...
# 19  netgear 108 mbps wireless firewall   port\nrou...
# 20  muniz \ngovenment don   want me to sell\nunder...
# 21  haley \ntechlite  inc    tcbb  thlt \njoint ve...
# 22  tinydrive    gb      25      inches       \n  ...
# 23  direct to you\nwarehouse direct\n   discounts\...
# 24  hello   have  special offer for you   \nwant t...
# 25  ready  decide eye  heard  once written son  vo...
# 26  discount rx is simple  quick  and affordable  ...
# 27  tonya could feel the glow of the hundreds of c...
# 28  hi  this is for sure one of the best pahrma we...
# 29  visit  http    www  computron  me  com for dea...
# 30  dear friend \nplease don   be surprised to rec...
# 31  logo stationery design\nplease visit our site ...
# 32  then  the shower stopped  and he waved good ni...
# 33  watson \nmedg  our best pick with rapid growth...
# 34  english\nfranais\ndeutsch\nartprice holds arch...
# 35  our us licensed doctors will\nprescribes your ...
#
#                                          POS_tags_sub  \
# 0   [(photoshop, NN), (windows, VBZ), (office, NN)...
# 1   [(looking, VBG), (for, IN), (medication, NN), ...
# 2   [(vocable, JJ), (rnd, NN), (word, NN), (asceti...
# 3                         [(report, NN), (01405, CD)]
# 4                   [(vic, JJ), (odin, NN), (ow, NN)]
# 5   [(underpriced, JJ), (issue, NN), (with, IN), (...
# 6   [(jump, NN), (in, IN), (to, TO), (gain, VB), (...
# 7   [(end, NN), (of, IN), (year, NN), (clearance, ...
# 8   [(vlc, NN), (dln, NN), (for, IN), (sale, NN), ...
# 9                                    [(jennifer, NN)]
# 10                                   [(software, NN)]
# 11  [(security, NN), (alert, NN), (on, IN), (micro...
# 12  [(instant, NN), (download, NN), (1300, CD), (p...
# 13      [(notification, NN), (of, IN), (bequest, NN)]
# 14  [(the, DT), (bull, NN), (reccomends, VBZ), (th...
# 15  [(are, VBP), (husband, NN), (soup, NN), (would...
# 16            [(active, JJ), (and, CC), (strong, JJ)]
# 17                                       [(back, RB)]
# 18                        [(new, JJ), (schedule, NN)]
# 19  [(108, CD), (mbps, JJ), (wireless, NN), (firew...
# 20                                     [(vulgar, NN)]
# 21  [(small, JJ), (stock, NN), (oppurtunities, NNS...
# 22  [(tinydrive, JJ), (usb, NN), (mobile, JJ), (gb...
# 23  [(what, WP), (she, PRP), (doesnt, VBD), (know,...
# 24  [(lose, JJ), (19, CD), (powerful, JJ), (weight...
# 25                   [(about, IN), (celebration, NN)]
# 26  [(cialis, NN), (valium, NN), (viagra, NN), (xa...
# 27                      [(young, JJ), (pussies, NNS)]
# 28  [(the, DT), (bast, NN), (phharma, NN), (out, I...
# 29             [(notebookplus, JJ), (batteries, NNS)]
# 30            [(from, IN), (mrs, CD), (juliana, NNS)]
# 31                                        [(cat, NN)]
# 32  [(my, PRP$), (brother, NN), (dream, NN), (one,...
# 33  [(collene, NN), (medg, NN), (stockplay, NN), (...
# 34  [(access, NN), (to, TO), (the, DT), (images, N...
# 35  [(are, VBP), (the, DT), (cat, NN), (raised, VBD)]
#
#                                         POS_tags_cont
# 0   [(abasements, NNS), (darer, VBP), (prudently, ...
# 1   [(it, PRP), (is, VBZ), (difficult, JJ), (to, T...
# 2   [(vcsc, NNS), (brand, NN), (new, JJ), (stock, ...
# 3   [(wffur, JJ), (attion, NN), (brom, NN), (est, ...
# 4   [(berne, JJ), (hotbox, NN), (carnal, JJ), (bri...
# 5   [(stock, NN), (report, NN), (dont, VBD), (siee...
# 6   [(we, PRP), (are, VBP), (very, RB), (excited, ...
# 7   [(item, NN), (no, DT), (description, NN), (pri...
# 8   [(enjoy, VB), (up, IN), (to, TO), (80, CD), (o...
# 9   [(sends, VBZ), (them, PRP), (to, TO), (their, ...
# 10  [(microsoft, JJ), (windows, NNS), (xp, VBP), (...
# 11  [(dear, JJ), (suntrust, NN), (bank, NN), (cust...
# 12  [(lost, VBN), (lips, NNS), (played, VBD), (sun...
# 13  [(from, IN), (dr, JJ), (abdul, NN), (kareem, V...
# 14  [(yap, NN), (internationa, NN), (inc, NN), (yp...
# 15  [(as, IN), (you, PRP), (know, VBP), (election,...
# 16  [(cialis, NN), (helps, VBZ), (increase, VB), (...
# 17  [(emile, IN), (the, DT), (cablefilterz, NN), (...
# 18  [(cry, NN), (born, JJ), (cow, NN), (mount, NN)...
# 19  [(netgear, JJ), (108, CD), (mbps, NN), (wirele...
# 20  [(muniz, JJ), (govenment, NN), (don, NN), (wan...
# 21  [(haley, NN), (techlite, NN), (inc, NN), (tcbb...
# 22  [(tinydrive, JJ), (gb, NN), (25, CD), (inches,...
# 23  [(direct, JJ), (to, TO), (you, PRP), (warehous...
# 24  [(hello, NNS), (have, VBP), (special, JJ), (of...
# 25  [(ready, JJ), (decide, VB), (eye, NN), (heard,...
# 26  [(discount, NN), (rx, NN), (is, VBZ), (simple,...
# 27  [(tonya, NN), (could, MD), (feel, VB), (the, D...
# 28  [(hi, NN), (this, DT), (is, VBZ), (for, IN), (...
# 29  [(visit, NN), (http, NN), (www, NN), (computro...
# 30  [(dear, JJ), (friend, NN), (please, NN), (don,...
# 31  [(logo, JJ), (stationery, NN), (design, NN), (...
# 32  [(then, RB), (the, DT), (shower, NN), (stopped...
# 33  [(watson, NN), (medg, VBZ), (our, PRP$), (best...
# 34  [(english, JJ), (franais, NN), (deutsch, NN), ...
# 35  [(our, PRP$), (us, PRP), (licensed, VBN), (doc...

# %%
most_common_words_for_pos(data['POS_tags_sub'],"NN")
# Out:
# [('cat', 2),
#  ('images', 2),
#  ('catalogues', 2),
#  ('photoshop', 1),
#  ('office', 1),
#  ('trending', 1),
#  ('medication', 1),
#  ('source', 1),
#  ('rnd', 1),
#  ('word', 1)]

# %%
common_sub_nouns = most_common_words_for_pos(data['POS_tags_sub'], 'NN')
print("10 most common nouns in the subject of the email:")
print(common_sub_nouns)
# Out:
# 10 most common nouns in the subject of the email:
# [('cat', 2), ('images', 2), ('catalogues', 2), ('photoshop', 1), ('office', 1), ('trending', 1), ('medication', 1), ('source', 1), ('rnd', 1), ('word', 1)]

# %%
common_sub_adj = most_common_words_for_pos(data['POS_tags_sub'], 'JJ')
print("10 most common adjective in the subject of the email:")
print(common_sub_adj)
# Out:
# 10 most common adjective in the subject of the email:
# [('main', 1), ('best', 1), ('vocable', 1), ('vic', 1), ('underpriced', 1), ('high', 1), ('substantial', 1), ('prior', 1), ('microsoft', 1), ('popular', 1)]

# %%
common_sub_verbs = most_common_words_for_pos(data['POS_tags_sub'], 'VB')
print("10 most common verb in the subject of the email:")
print(common_sub_verbs)
# Out:
# 10 most common verb in the subject of the email:
# [('are', 4), ('needed', 2), ('windows', 1), ('looking', 1), ('gain', 1), ('crip', 1), ('reccomends', 1), ('be', 1), ('doesnt', 1), ('accedez', 1)]

# %%
common_cont_nouns = most_common_words_for_pos(data['POS_tags_cont'], 'NN')
print("10 most common noun in the content of the email:")
print(common_cont_nouns)
# Out:
# 10 most common noun in the content of the email:
# [('company', 68), ('statements', 45), ('information', 37), ('report', 32), ('price', 27), ('securities', 23), ('computron', 23), ('section', 21), ('stock', 20), ('companies', 20)]

# %%
common_cont_adj = most_common_words_for_pos(data['POS_tags_cont'], 'JJ')
print("10 most common verb in the content of the email:")
print(common_cont_adj)
# Out:
# 10 most common verb in the content of the email:
# [('future', 22), ('other', 20), ('many', 18), ('personal', 18), ('more', 16), ('new', 13), ('such', 13), ('usb', 13), ('free', 13), ('online', 11)]

# %%
common_cont_verb = most_common_words_for_pos(data['POS_tags_cont'], 'VB')
print("10 most common verb in the content of the email:")
print(common_cont_verb)
# Out:
# 10 most common verb in the content of the email:
# [('is', 96), ('be', 83), ('are', 55), ('has', 34), ('was', 30), ('have', 28), ('com', 15), ('been', 13), ('looking', 11), ('include', 11)]

# %%
print("\nDataFrame with POS tags:")
print(data)
# Out:
# DataFrame with POS tags:
#                                               Subject  \
# 0   photoshop , windows , office . cheap . main tr...
# 1   looking for medication ? we ` re the best sour...
# 2                 vocable % rnd - word asceticism\n\n
# 3                                    report 01405 !\n
# 4                                 vic . odin n ^ ow\n
# 5      underpriced issue with high return on equity\n
# 6    jump in to gain substantial ground immediately\n
# 7                             end of year clearance\n
# 8   vlc , 0 dln for sale , no prior pres . crip . ...
# 9                                          jennifer\n
# 10                                         software\n
# 11    security alert on microsoft internet explorer\n
# 12      instant download 1300 popular softwares now\n
# 13                          notification of bequest\n
# 14                the bull reccomends this stokkpic\n
# 15                       re : husband soup would be\n
# 16                                active and strong\n
# 17                                             back\n
# 18                                     new schedule\n
# 19  108 mbps wireless firewall 4 - port router @ $...
# 20                                           vulgar\n
# 21       small stock oppurtunities - their shooting\n
# 22  tinydrive usb 2 . 0 mobile 2 . 2 gb storage dr...
# 23                what she doesnt know sprig bashaw\n
# 24  lose 19 % , powerful weightloss now available ...
# 25                                about celebration\n
# 26  cialis , valium , viagra , xanax at low price ...
# 27                                    young pussies\n
# 28   the bast phharma out ther - same da - y shijp...
# 29                           notebookplus batteries\n
# 30                               from mrs . juliana\n
# 31                                              cat\n
# 32   my brother ' s dream one nlght , i lay in bed...
# 33           collene medg stockplay of the day jeer\n
# 34  access to the images of the catalogues - acced...
# 35                             re :  the cat raised\n
#
#                                               Content  \
# 0   abasements darer prudently fortuitous undergon...
# 1   it is difficult to make our material condition...
# 2   vcsc - brand new stock for your attention\nvoc...
# 3   wffur attion brom est inst siupied 1 pgst our ...
# 4   berne hotbox carnal bride cutworm dyadic\nguar...
# 5   stock report .\ndont sieep on this stock ! thi...
# 6   we are very excited about this new upcoming st...
# 7   item no #\ndescription\nprice $\n1 .\n2 . 2 gb...
# 8   enjoy up to 80 % off\nbuy vlc , 0 dln online\n...
# 9   sends them to their final destination .\ndesig...
# 10  microsoft windows xp professioznal 2002\nretai...
# 11  dear suntrust bank customer ,\nto provide our ...
# 12  lost lips played sun . remained profession spr...
# 13  from : dr . abdul kareem\nkareem co . ( solici...
# 14  yap internationa | , inc . ( ypil )\nvoip tech...
# 15  as you know election time is not the best thin...
# 16  cialis helps increase blood flow in the penis ...
# 17  emile (\nthe cablefilterz will allow you to re...
# 18  cry born , cow mount record middle . govern , ...
# 19  netgear 108 mbps wireless firewall 4 - port\nr...
# 20  muniz ,\ngovenment don ' t want me to sell\nun...
# 21  haley ,\ntechlite , inc . ( 0 tcbb : thlt )\nj...
# 22  tinydrive 2 . 2 gb . 5 x 2 . 25 x 2 . 5 - inch...
# 23  direct to you\nwarehouse direct\nr _ x discoun...
# 24  hello , i have a special offer for you . . .\n...
# 25  ready , decide eye , heard . once written son ...
# 26  discount rx is simple , quick , and affordable...
# 27  tonya could feel the glow of the hundreds of c...
# 28  hi ! this is for sure one of the best pahrma w...
# 29  visit : http : / / www . computron - me . com ...
# 30  dear friend ,\nplease don ' t be surprised to ...
# 31  logo stationery design\nplease visit our site ...
# 32  then , the shower stopped , and he waved good ...
# 33  watson ,\nmedg - our best pick with rapid grow...
# 34  english\nfranais\ndeutsch\nartprice holds arch...
# 35  our us licensed doctors will\nprescribes your ...
#
#                                         Clean_Subject  \
# 0   photoshop  windows  office  cheap  main trendi...
# 1   looking for medication  we  are the best sourc...
# 2                   vocable  rnd  word asceticism\n\n
# 3                                     report 01405 \n
# 4                                    vic  odin   ow\n
# 5      underpriced issue with high return on equity\n
# 6    jump in to gain substantial ground immediately\n
# 7                             end of year clearance\n
# 8   vlc   dln for sale  no prior pres  crip  tion ...
# 9                                          jennifer\n
# 10                                         software\n
# 11    security alert on microsoft internet explorer\n
# 12      instant download 1300 popular softwares now\n
# 13                          notification of bequest\n
# 14                the bull reccomends this stokkpic\n
# 15                       are  husband soup would be\n
# 16                                active and strong\n
# 17                                             back\n
# 18                                     new schedule\n
# 19  108 mbps wireless firewall   port router   59 ...
# 20                                           vulgar\n
# 21        small stock oppurtunities  their shooting\n
# 22  tinydrive usb    mobile    gb storage drive   ...
# 23                what she doesnt know sprig bashaw\n
# 24  lose 19   powerful weightloss now available wh...
# 25                                about celebration\n
# 26  cialis  valium  viagra  xanax at low price  no...
# 27                                    young pussies\n
# 28   the bast phharma out ther  same da   shijppin...
# 29                           notebookplus batteries\n
# 30                                from mrs  juliana\n
# 31                                              cat\n
# 32   my brother   dream one nlght   lay in bed rea...
# 33           collene medg stockplay of the day jeer\n
# 34  access to the images of the catalogues  accede...
# 35                             are   the cat raised\n
#
#                                         Clean_Content  \
# 0   abasements darer prudently fortuitous undergon...
# 1   it is difficult to make our material condition...
# 2   vcsc  brand new stock for your attention\nvoca...
# 3   wffur attion brom est inst siupied  pgst our r...
# 4   berne hotbox carnal bride cutworm dyadic\nguar...
# 5   stock report \ndont sieep on this stock  this ...
# 6   we are very excited about this new upcoming st...
# 7   item no \ndescription\nprice \n \n   gb compac...
# 8   enjoy up to 80  off\nbuy vlc   dln online\nget...
# 9   sends them to their final destination \ndesign...
# 10  microsoft windows xp professioznal 2002\nretai...
# 11  dear suntrust bank customer \nto provide our c...
# 12  lost lips played sun  remained profession spri...
# 13  from  dr  abdul kareem\nkareem co   solicitors...
# 14  yap internationa   inc   ypil \nvoip technoiog...
# 15  as you know election time is not the best thin...
# 16  cialis helps increase blood flow in the penis ...
# 17  emile \nthe cablefilterz will allow you to rec...
# 18  cry born  cow mount record middle  govern  nor...
# 19  netgear 108 mbps wireless firewall   port\nrou...
# 20  muniz \ngovenment don   want me to sell\nunder...
# 21  haley \ntechlite  inc    tcbb  thlt \njoint ve...
# 22  tinydrive    gb      25      inches       \n  ...
# 23  direct to you\nwarehouse direct\n   discounts\...
# 24  hello   have  special offer for you   \nwant t...
# 25  ready  decide eye  heard  once written son  vo...
# 26  discount rx is simple  quick  and affordable  ...
# 27  tonya could feel the glow of the hundreds of c...
# 28  hi  this is for sure one of the best pahrma we...
# 29  visit  http    www  computron  me  com for dea...
# 30  dear friend \nplease don   be surprised to rec...
# 31  logo stationery design\nplease visit our site ...
# 32  then  the shower stopped  and he waved good ni...
# 33  watson \nmedg  our best pick with rapid growth...
# 34  english\nfranais\ndeutsch\nartprice holds arch...
# 35  our us licensed doctors will\nprescribes your ...
#
#                                          POS_tags_sub  \
# 0   [(photoshop, NN), (windows, VBZ), (office, NN)...
# 1   [(looking, VBG), (for, IN), (medication, NN), ...
# 2   [(vocable, JJ), (rnd, NN), (word, NN), (asceti...
# 3                         [(report, NN), (01405, CD)]
# 4                   [(vic, JJ), (odin, NN), (ow, NN)]
# 5   [(underpriced, JJ), (issue, NN), (with, IN), (...
# 6   [(jump, NN), (in, IN), (to, TO), (gain, VB), (...
# 7   [(end, NN), (of, IN), (year, NN), (clearance, ...
# 8   [(vlc, NN), (dln, NN), (for, IN), (sale, NN), ...
# 9                                    [(jennifer, NN)]
# 10                                   [(software, NN)]
# 11  [(security, NN), (alert, NN), (on, IN), (micro...
# 12  [(instant, NN), (download, NN), (1300, CD), (p...
# 13      [(notification, NN), (of, IN), (bequest, NN)]
# 14  [(the, DT), (bull, NN), (reccomends, VBZ), (th...
# 15  [(are, VBP), (husband, NN), (soup, NN), (would...
# 16            [(active, JJ), (and, CC), (strong, JJ)]
# 17                                       [(back, RB)]
# 18                        [(new, JJ), (schedule, NN)]
# 19  [(108, CD), (mbps, JJ), (wireless, NN), (firew...
# 20                                     [(vulgar, NN)]
# 21  [(small, JJ), (stock, NN), (oppurtunities, NNS...
# 22  [(tinydrive, JJ), (usb, NN), (mobile, JJ), (gb...
# 23  [(what, WP), (she, PRP), (doesnt, VBD), (know,...
# 24  [(lose, JJ), (19, CD), (powerful, JJ), (weight...
# 25                   [(about, IN), (celebration, NN)]
# 26  [(cialis, NN), (valium, NN), (viagra, NN), (xa...
# 27                      [(young, JJ), (pussies, NNS)]
# 28  [(the, DT), (bast, NN), (phharma, NN), (out, I...
# 29             [(notebookplus, JJ), (batteries, NNS)]
# 30            [(from, IN), (mrs, CD), (juliana, NNS)]
# 31                                        [(cat, NN)]
# 32  [(my, PRP$), (brother, NN), (dream, NN), (one,...
# 33  [(collene, NN), (medg, NN), (stockplay, NN), (...
# 34  [(access, NN), (to, TO), (the, DT), (images, N...
# 35  [(are, VBP), (the, DT), (cat, NN), (raised, VBD)]
#
#                                         POS_tags_cont
# 0   [(abasements, NNS), (darer, VBP), (prudently, ...
# 1   [(it, PRP), (is, VBZ), (difficult, JJ), (to, T...
# 2   [(vcsc, NNS), (brand, NN), (new, JJ), (stock, ...
# 3   [(wffur, JJ), (attion, NN), (brom, NN), (est, ...
# 4   [(berne, JJ), (hotbox, NN), (carnal, JJ), (bri...
# 5   [(stock, NN), (report, NN), (dont, VBD), (siee...
# 6   [(we, PRP), (are, VBP), (very, RB), (excited, ...
# 7   [(item, NN), (no, DT), (description, NN), (pri...
# 8   [(enjoy, VB), (up, IN), (to, TO), (80, CD), (o...
# 9   [(sends, VBZ), (them, PRP), (to, TO), (their, ...
# 10  [(microsoft, JJ), (windows, NNS), (xp, VBP), (...
# 11  [(dear, JJ), (suntrust, NN), (bank, NN), (cust...
# 12  [(lost, VBN), (lips, NNS), (played, VBD), (sun...
# 13  [(from, IN), (dr, JJ), (abdul, NN), (kareem, V...
# 14  [(yap, NN), (internationa, NN), (inc, NN), (yp...
# 15  [(as, IN), (you, PRP), (know, VBP), (election,...
# 16  [(cialis, NN), (helps, VBZ), (increase, VB), (...
# 17  [(emile, IN), (the, DT), (cablefilterz, NN), (...
# 18  [(cry, NN), (born, JJ), (cow, NN), (mount, NN)...
# 19  [(netgear, JJ), (108, CD), (mbps, NN), (wirele...
# 20  [(muniz, JJ), (govenment, NN), (don, NN), (wan...
# 21  [(haley, NN), (techlite, NN), (inc, NN), (tcbb...
# 22  [(tinydrive, JJ), (gb, NN), (25, CD), (inches,...
# 23  [(direct, JJ), (to, TO), (you, PRP), (warehous...
# 24  [(hello, NNS), (have, VBP), (special, JJ), (of...
# 25  [(ready, JJ), (decide, VB), (eye, NN), (heard,...
# 26  [(discount, NN), (rx, NN), (is, VBZ), (simple,...
# 27  [(tonya, NN), (could, MD), (feel, VB), (the, D...
# 28  [(hi, NN), (this, DT), (is, VBZ), (for, IN), (...
# 29  [(visit, NN), (http, NN), (www, NN), (computro...
# 30  [(dear, JJ), (friend, NN), (please, NN), (don,...
# 31  [(logo, JJ), (stationery, NN), (design, NN), (...
# 32  [(then, RB), (the, DT), (shower, NN), (stopped...
# 33  [(watson, NN), (medg, VBZ), (our, PRP$), (best...
# 34  [(english, JJ), (franais, NN), (deutsch, NN), ...
# 35  [(our, PRP$), (us, PRP), (licensed, VBN), (doc...

# %%
def collect_pos_tags(text):
    tokens = word_tokenize(text)
    pos_tags = pos_tag(tokens)
    noun_list = [word for word, pos in pos_tags if pos.startswith('NN')]
    adj_list = [word for word, pos in pos_tags if pos.startswith('JJ')]
    verb_list = [word for word, pos in pos_tags if pos.startswith('VB')]
    return {
        'nouns': noun_list,
        'adjectives': adj_list,
        'verbs': verb_list
    }

# %%
data['pos_tags_sub'] = data['Clean_Subject'].apply(collect_pos_tags)
# Out:
# 0     {'nouns': ['photoshop', 'office', 'trending'],...
# 1     {'nouns': ['medication', 'source'], 'adjective...
# 2     {'nouns': ['rnd', 'word', 'asceticism'], 'adje...
# 3     {'nouns': ['report'], 'adjectives': [], 'verbs...
# 4     {'nouns': ['odin', 'ow'], 'adjectives': ['vic'...
# 5     {'nouns': ['issue', 'return', 'equity'], 'adje...
# 6     {'nouns': ['jump', 'ground'], 'adjectives': ['...
# 7     {'nouns': ['end', 'year', 'clearance'], 'adjec...
# 8     {'nouns': ['vlc', 'dln', 'sale', 'pres', 'tion...
# 9     {'nouns': ['jennifer'], 'adjectives': [], 'ver...
# 10    {'nouns': ['software'], 'adjectives': [], 'ver...
# 11    {'nouns': ['security', 'alert', 'internet', 'e...
# 12    {'nouns': ['instant', 'download', 'softwares']...
# 13    {'nouns': ['notification', 'bequest'], 'adject...
# 14    {'nouns': ['bull', 'stokkpic'], 'adjectives': ...
# 15    {'nouns': ['husband', 'soup'], 'adjectives': [...
# 16    {'nouns': [], 'adjectives': ['active', 'strong...
# 17         {'nouns': [], 'adjectives': [], 'verbs': []}
# 18    {'nouns': ['schedule'], 'adjectives': ['new'],...
# 19    {'nouns': ['wireless', 'firewall', 'port', 'ro...
# 20    {'nouns': ['vulgar'], 'adjectives': [], 'verbs...
# 21    {'nouns': ['stock', 'oppurtunities', 'shooting...
# 22    {'nouns': ['usb', 'storage', 'drive'], 'adject...
# 23    {'nouns': ['sprig', 'bashaw'], 'adjectives': [...
# 24    {'nouns': ['weightloss'], 'adjectives': ['lose...
# 25    {'nouns': ['celebration'], 'adjectives': [], '...
# 26    {'nouns': ['cialis', 'valium', 'viagra', 'xana...
# 27    {'nouns': ['pussies'], 'adjectives': ['young']...
# 28    {'nouns': ['bast', 'phharma', 'ther', 'da', 's...
# 29    {'nouns': ['batteries'], 'adjectives': ['noteb...
# 30    {'nouns': ['juliana'], 'adjectives': [], 'verb...
# 31    {'nouns': ['cat'], 'adjectives': [], 'verbs': []}
# 32    {'nouns': ['brother', 'dream', 'nlght', 'lay',...
# 33    {'nouns': ['collene', 'medg', 'stockplay', 'da...
# 34    {'nouns': ['access', 'images', 'catalogues', '...
# 35    {'nouns': ['cat'], 'adjectives': [], 'verbs': ...
# Name: pos_tags_sub, dtype: object

# %%
noun_adj_verb_sub = pd.DataFrame(data['pos_tags_sub'].tolist())

# %%
noun_adj_verb_sub
# Out:
#                                                 nouns  \
# 0                       [photoshop, office, trending]
# 1                                [medication, source]
# 2                             [rnd, word, asceticism]
# 3                                            [report]
# 4                                          [odin, ow]
# 5                             [issue, return, equity]
# 6                                      [jump, ground]
# 7                              [end, year, clearance]
# 8                        [vlc, dln, sale, pres, tion]
# 9                                          [jennifer]
# 10                                         [software]
# 11              [security, alert, internet, explorer]
# 12                     [instant, download, softwares]
# 13                            [notification, bequest]
# 14                                   [bull, stokkpic]
# 15                                    [husband, soup]
# 16                                                 []
# 17                                                 []
# 18                                         [schedule]
# 19                 [wireless, firewall, port, router]
# 20                                           [vulgar]
# 21                   [stock, oppurtunities, shooting]
# 22                              [usb, storage, drive]
# 23                                    [sprig, bashaw]
# 24                                       [weightloss]
# 25                                      [celebration]
# 26  [cialis, valium, viagra, xanax, price, prescri...
# 27                                          [pussies]
# 28     [bast, phharma, ther, da, shijpping, chromium]
# 29                                        [batteries]
# 30                                          [juliana]
# 31                                              [cat]
# 32  [brother, dream, nlght, lay, bed, reading, hea...
# 33              [collene, medg, stockplay, day, jeer]
# 34  [access, images, catalogues, images, des, cata...
# 35                                              [cat]
#
#                      adjectives           verbs
# 0                        [main]       [windows]
# 1                        [best]  [looking, are]
# 2                     [vocable]              []
# 3                            []              []
# 4                         [vic]              []
# 5           [underpriced, high]              []
# 6                 [substantial]          [gain]
# 7                            []              []
# 8                       [prior]  [crip, needed]
# 9                            []              []
# 10                           []              []
# 11                  [microsoft]              []
# 12                    [popular]              []
# 13                           []              []
# 14                           []    [reccomends]
# 15                           []       [are, be]
# 16             [active, strong]              []
# 17                           []              []
# 18                        [new]              []
# 19                       [mbps]              []
# 20                           []              []
# 21                      [small]              []
# 22      [tinydrive, mobile, gb]              []
# 23                       [know]        [doesnt]
# 24  [lose, powerful, available]           [are]
# 25                           []              []
# 26                        [low]        [needed]
# 27                      [young]              []
# 28                       [same]              []
# 29               [notebookplus]              []
# 30                           []              []
# 31                           []              []
# 32                           []              []
# 33                           []              []
# 34                        [aux]       [accedez]
# 35                           []   [are, raised]

# %%
data['pos_tags_cont'] = data['Clean_Content'].apply(collect_pos_tags)
noun_adj_verb_cont = pd.DataFrame(data['pos_tags_cont'].tolist()) = pd.DataFrame(data['pos_tags_cont'].tolist())

# %%
noun_adj_verb_cont
# Out:
#                                                 nouns  \
# 0   [abasements, undergone, charm, orinoco, taster...
# 1   [material, condition, law, laws, site, medicat...
# 2   [vcsc, brand, stock, attention, vocalscape, st...
# 3   [attion, brom, inst, riwe, tont, cons, benco, ...
# 4   [hotbox, bride, cutworm, guardia, gremlin, cou...
# 5   [stock, report, stock, company, transactions, ...
# 6   [stock, oil, gas, inc, mogi, opportunities, ca...
# 7   [item, description, price, gb, flash, type, ii...
# 8   [buy, dln, online, gra, cla, lum, get, online,...
# 9          [destination, keys, someone, match, owner]
# 10  [windows, price, pricie, adobe, photoshkop, pr...
# 11  [suntrust, bank, customer, customers, access, ...
# 12  [lips, sun, profession, spring, group, speak, ...
# 13  [abdul, solicitors, osiyemi, ikeja, lagos, tel...
# 14  [yap, internationa, inc, ypil, voip, technoiog...
# 15  [election, time, thing, economy, economy, cond...
# 16  [cialis, blood, flow, penis, man, cialis, men,...
# 17  [cablefilterz, channels, order, remote, contro...
# 18  [cry, cow, mount, record, middle, problem, wor...
# 19  [mbps, wireless, firewall, port, router, fast,...
# 20  [govenment, don, spouse, staff, credit, histor...
# 21  [haley, techlite, inc, tcbb, thlt, venture, ag...
# 22  [gb, inches, storage, design, visit, http, www...
# 23  [discounts, info, size, dog, fight, size, figh...
# 24  [hello, offer, weightloss, prescription, adipr...
# 25  [eye, heard, son, vowel, thank, mother, histor...
# 26  [discount, rx, br, today, prescription, drugs,...
# 27  [tonya, glow, hundreds, candles, bare, hair, f...
# 28  [hi, pahrma, deels, pharmma, hesitate, alb, cl...
# 29  [visit, http, www, computron, deals, stop, dis...
# 30  [friend, please, don, letter, juliana, mbuluku...
# 31  [stationery, design, please, site, http, logo,...
# 32  [shower, night, room, hour, book, light, lay, ...
# 33  [watson, pick, growth, medianet, group, contra...
# 34  [franais, deutsch, artprice, archives, auction...
# 35  [doctors, medication, medications, door, phent...
#
#                                            adjectives  \
# 0   [fortuitous, affluent, pornographic, cuvier, b...
# 1   [difficult, best, easy, bad, best, simpliest, ...
# 2   [new, vcsc, top, april, low, next, crazy, next...
# 3   [wffur, est, pgst, tew, ust, inenced, ve, oite...
# 4   [berne, carnal, dyadic, continuous, akin, voca...
# 5   [hot, inc, strong, long, inc, porta, proprieta...
# 6   [excited, new, upcoming, montana, further, alb...
# 7   [compact, ext, serial, usb, external, web, cla...
# 8   [vla, val, cheap, many, available, required, f...
# 9             [final, private, key, validate, public]
# 10  [microsoft, professioznal, retail, low, retail...
# 11  [dear, effective, secure, online, upgrading, n...
# 12  [able, evil, froma, enough, needed, right, hot...
# 13  [dr, co, akin, nigeria, fastermail, sequel, no...
# 14  [high, current, littie, realiy, more, unheard,...
# 15              [best, unstable, long, last, orbital]
# 16                 [erectile, sexual, sexual, active]
# 17                                          [special]
# 18  [born, govern, song, invent, strong, many, twe...
# 19  [netgear, super, netgear, netgear, wireless, s...
# 20             [muniz, undergroundcd, own, com, open]
# 21  [joint, anticipated, mi, new, outstanding, cur...
# 22  [tinydrive, gigabytesmobile, lightweight, comp...
# 23    [direct, direct, best, available, more, sunday]
# 24  [special, powerful, available, natural, weight...
# 25  [ready, song, large, general, short, sharp, co...
# 26  [simple, quick, affordable, many, usedbr, many...
# 27                  [horrible, beautiful, slid, warm]
# 28  [sure, best, special, more, nah, blank, calvar...
# 29  [free, uae, latest, contact, further, net, aeo...
# 30  [dear, other, mrs, late, online, gem, diplomat...
# 31  [logo, ru, corporate, envelops, professional, ...
# 32                   [good, sleep, other, didn, open]
# 33  [best, rapid, several, short, bottom, outstand...
# 34  [english, more, present, public, same, public,...
# 35  [free, overnight, ulltram, many, many, weight,...
#
#                                                 verbs
# 0   [darer, lighthearted, robed, bayda, inconvenie...
# 1   [is, make, is, ruin, found, see, ve, got, want...
# 2   [inc, is, be, expected, bounce, level, hit, bo...
# 3   [siupied, rest, presyou, aicy, graghteave, yur...
# 4                                   [born, consulate]
# 5   [dont, is, gaming, breaking, gaming, eading, g...
# 6   [are, explode, explore, is, coveted, want, wat...
# 7   [micro, keyboard, modem, play, built, pen, web...
# 8                              [enjoy, get, lls, buy]
# 9     [sends, designated, wants, meet, be, purported]
# 10  [xp, save, savue, savxe, savxe, suite, save, s...
# 11  [provide, are, add, are, support, know, has, v...
# 12  [lost, played, remained, stood, climbing, know...
# 13  [kareem, kareem, advocates, karol, is, ksm, no...
# 14  [requires, thursday, have, been, moving, move,...
# 15  [know, is, is, see, are, going, goes, have, av...
# 16  [helps, increase, is, stimulated, helps, keep,...
# 17             [allow, receive, payperviews, hosting]
# 18  [go, see, are, east, page, am, burn, zoomsspar...
# 19  [is, used, delivers, speeds, using, has, distr...
# 20  [want, sell, check, investigate, hacking, disa...
# 21  [loq, is, are, fiying, know, is, traded, is, n...
# 22  [driveusb, com, drive, provides, designed, tak...
# 23                        [is, try, finding, plumber]
# 24  [have, want, lose, is, lose, dieting, increase...
# 25  [decide, written, depend, differ, feel, walk, ...
# 26                         [is, offering, click, php]
# 27  [feel, skin, was, plastered, thought, have, lo...
# 28             [is, offer, give, enter, don, buzzing]
# 29  [com, com, listing, please, send, com, dell, c...
# 30  [be, surprised, receive, do, know, am, makele,...
# 31      [visit, letterheads, brochures, design, john]
# 32  [stopped, waved, passed, continued, read, put,...
# 33  [medg, expected, technologies, medg, be, being...
# 34  [holds, containing, is, reproduced, provide, c...
# 35    [licensed, prescribes, shipped, show, doomsday]
